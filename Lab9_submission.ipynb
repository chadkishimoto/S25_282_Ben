# %% [markdown]
# ## Replace this text with your name

# %% [markdown]
# In the cell below, include **all** your ``import`` statements

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create a histogram of standard normal random numbers. (If there are issues, remember that you need to initialize ``rng``, your random number generator.

# %%
rng = np.random.default_rng()
random_vals_new2 = rng.standard_normal(1000000)
plt.figure()
plt.hist(random_vals_new2,100)
plt.show()

# %% [markdown]
# Create a function that takes an integer, ``N``, as an input and outputs an array of length N that represents a random walk using either +1 or -1 as the step.

# %%
def walk_path(num_steps):

    location = np.zeros(num_steps)
    location[0] = 0
    for i in range(1,num_steps):
        location[i] = location[i-1] + rng.choice((-1,1))
    return location


plt.figure()
plt.plot(walk_path(100), '-o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Exercise**: Gaussian (standard normal) random walks. Use ``rng.standard_normal()`` to determine the step size. Now, not only can the step be positive or negative, but its size can vary. This will lead to smoother (and sometimes crazier) looking results. In the cell below, include all the code needed to:
# - A function that takes N as an input and outputs an array of length N that is a random walk whose steps are chosen by taking standard normal steps.
# - Create a matrix of 2000 trials, each of 100 steps
# - Plot 100 of these trials
# - Calculate msd at each of the 100 time steps
# - Plot msd vs. time and include a second plot with the $D = 0.5$ model curve.

# %%
def walk_path(num_steps):

    location = np.zeros(num_steps)
    location[0] = 0
    for i in range(1,num_steps):
        location[i] = location[i-1] + rng.choice((-1,1))
    return location

matrix_of_walks = np.zeros((2000, 100))
msd_vals = np.zeros(100)
time = np.arange(100)


for i in range(2000):
    matrix_of_walks[i,:] = walk_path(100)
    
for i in range(100):
    plt.title("MSD vs Time")
    plt.xlabel("Time")
    plt.ylabel("MSD")
    plt.plot(time, matrix_of_walks[i,:])
    msd_vals[i] = np.mean(matrix_of_walks[:,i]**2)


plt.figure()
plt.plot(time, msd_vals)
plt.plot(time,time)
plt.title("MSD vs Time")
plt.xlabel("Time")
plt.ylabel("MSD")
plt.show()

# %% [markdown]
# Confirm that this all works by using ``Kernel > Restart Kernel and Run All Cells...``

# %% [markdown]
# When you are happy with your results, you will submit by uploading this file on Github.
